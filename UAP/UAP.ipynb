# %% [markdown]
# Nama: Khairy Zhafran H. Kastella
#
# NIM: 202210370311439
#
# Kelas: Penggalian Data B

# %% [markdown]
# 1. Import / Load Data

# %%
import pandas as pd

df = pd.read_csv("PD B Gensp.csv", sep=';')

# %% [markdown]
# Lakukan EDA

# %%
df.head()
# Out:
#    order_id  customer_id    restaurant_name    cuisine_type  \
# 0   1477722       347263        Dos Caminos         Mexican
# 1   1478319        84087  The Meatball Shop         Italian
# 2   1477650       284835        Shake Shack        American
# 3   1477960       375098          12 Chairs  Middle Eastern
# 4   1477278       347263       Hummus Place  Middle Eastern
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              12.08         Weekday          5                     26
# 1              16.49         Weekend          3                     22
# 2              15.57         Weekend          5                     32
# 3              29.10         Weekend  Not given                     22
# 4              16.15         Weekend          4                     30
#
#    delivery_time
# 0             26
# 1             28
# 2             17
# 3             26
# 4             28

# %%
df.tail()
# Out:
#      order_id  customer_id restaurant_name cuisine_type  cost_of_the_order  \
# 995   1477592        87357     Shake Shack     American              31.43
# 996   1476672       105385     Han Dynasty      Chinese               8.54
# 997   1477339        68965  RedFarm Hudson      Chinese              12.18
# 998   1476571       334758       Melt Shop     American              29.15
# 999   1477269       255697     Sushi Samba     Japanese               6.84
#
#     day_of_the_week     rating  food_preparation_time  delivery_time
# 995         Weekend          5                     30             19
# 996         Weekend          4                     31             15
# 997         Weekend  Not given                     20             18
# 998         Weekend          4                     26             17
# 999         Weekend          5                     27             20

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.000000e+03    1000.000000         1000.00000            1000.000000
# mean   1.477504e+06  173943.016000           16.75302              27.202000
# std    5.457057e+02  114741.212127            7.52092               4.705033
# min    1.476547e+06    5444.000000            4.66000              20.000000
# 25%    1.477024e+06   78939.000000           12.13000              23.000000
# 50%    1.477520e+06  129810.500000           14.48000              27.000000
# 75%    1.477973e+06  270464.250000           22.36000              31.000000
# max    1.478443e+06  405334.000000           35.41000              35.000000
#
#        delivery_time
# count    1000.000000
# mean       24.200000
# std         4.928924
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %%
df.isnull()
# Out:
#      order_id  customer_id  restaurant_name  cuisine_type  cost_of_the_order  \
# 0       False        False            False         False              False
# 1       False        False            False         False              False
# 2       False        False            False         False              False
# 3       False        False            False         False              False
# 4       False        False            False         False              False
# ..        ...          ...              ...           ...                ...
# 995     False        False            False         False              False
# 996     False        False            False         False              False
# 997     False        False            False         False              False
# 998     False        False            False         False              False
# 999     False        False            False         False              False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1000 non-null   int64
#  1   customer_id            1000 non-null   int64
#  2   restaurant_name        1000 non-null   object
#  3   cuisine_type           1000 non-null   object
#  4   cost_of_the_order      1000 non-null   float64
#  5   day_of_the_week        1000 non-null   object
#  6   rating                 1000 non-null   object
#  7   food_preparation_time  1000 non-null   int64
#  8   delivery_time          1000 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
df.notnull()
# Out:
#      order_id  customer_id  restaurant_name  cuisine_type  cost_of_the_order  \
# 0        True         True             True          True               True
# 1        True         True             True          True               True
# 2        True         True             True          True               True
# 3        True         True             True          True               True
# 4        True         True             True          True               True
# ..        ...          ...              ...           ...                ...
# 995      True         True             True          True               True
# 996      True         True             True          True               True
# 997      True         True             True          True               True
# 998      True         True             True          True               True
# 999      True         True             True          True               True
#
# ...

# %%
df.nunique()
# Out:
# order_id                 1000
# customer_id               762
# restaurant_name           142
# cuisine_type               14
# cost_of_the_order         253
# day_of_the_week             2
# rating                      4
# food_preparation_time      16
# delivery_time              19
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)

onehot_encoded = encoder.fit_transform(df[[]])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

df = pd.read_csv("PD B Genap.csv", sep=';')

train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, shuffle=True)

print(f"Train Set: {train_df.shape}")
# Out:
# Train Set: (700, 8)

# %%
df_encoded = pd.get_dummies(df, columns=['rating'])

scaler = MinMaxScaler()

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='kmeas++', random_state=42)
    kmeans.fit(df_encode[['rating', 'day_of_the_week']]) 
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11));
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluester')
plt.ylabel('WCSS')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

scatter_data_x = np.random.rand(20)
scatter_data_y = np.random.rand(20)

plt.figure(figsize=(8, 5))
plt.subplots(1, 1)
plt.scatter(scatter_data_x, scatter_data_y)
plt.title('Scatter')
# Out:
# Text(0.5, 1.0, 'Scatter')

# %%
from sklearn.neighbors import NearestNeighbors

nn = NearestNeighbors(metric='cosine', algorithm='brute')
